# %% [markdown]
# # Data science project
#
# 1. Loading data with pandas
# 2. Feature engineering
# 3. Scikit-learn

# %%
from loader import create_data

# %%
create_data()
# Out:
# [1, 39, 2, 4, 5, 9, 10]

# %% [markdown]
# # Imports in Python

# %% [markdown]
# 1. Is getting an instance of a library into our python session.
# 2. Excuting the script we import.

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/cor/Dropbox (Xebia)/projects/2003-dsm-kaiseraugst-advanced-ds-w-python/2003-dsm-kaiseraugst-advanced-ds-w-python/day01/example-project',
#  '/Users/cor/miniconda3/envs/example-project/lib/python37.zip',
#  '/Users/cor/miniconda3/envs/example-project/lib/python3.7',
#  '/Users/cor/miniconda3/envs/example-project/lib/python3.7/lib-dynload',
#  '',
#  '/Users/cor/miniconda3/envs/example-project/lib/python3.7/site-packages',
#  '/Users/cor/miniconda3/envs/example-project/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/cor/.ipython']

# %%
! ls /Users/cor/miniconda3/envs/example-project/lib/python3.7/site-packages
# Out:
# IPython
# Jinja2-2.11.1.dist-info
# MarkupSafe-1.1.1.dist-info
# PyQt5
# Pygments-2.6.1.dist-info
# QtPy-1.9.0.dist-info
# README.txt
# Send2Trash-1.5.0-py3.7.egg-info
# __pycache__
# _pyrsistent_version.py
# appnope
# appnope-0.1.0-py3.7.egg-info
# attr
# attrs-19.3.0.dist-info
# backcall
# backcall-0.1.0.dist-info
# bleach
# bleach-3.1.0-py3.7.egg-info
# certifi
# certifi-2019.11.28-py3.7.egg-info
# dateutil
# decorator-4.4.2.dist-info
# decorator.py
# defusedxml
# defusedxml-0.6.0-py2.7.egg-info
# easy_install.py
# entrypoints-0.3-py3.7.egg-info
# entrypoints.py
# flake8
# flake8-3.7.9.dist-info
# importlib_metadata
# importlib_metadata-1.5.0.dist-info
# ipykernel
# ipykernel-5.1.4.dist-info
# ipykernel_launcher.py
# ipython-7.13.0.dist-info
# ipython_genutils
# ipython_genutils-0.2.0-py3.7.egg-info
# ipywidgets
# ipywidgets-7.5.1.dist-info
# jedi
# jedi-0.16.0.dist-info
# jinja2
# jsonschema
# jsonschema-3.2.0.dist-info
# jupyter-1.0.0.dist-info
# jupyter.py
# jupyter_client
# ...

# %% [markdown]
# # Imports have cache

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  'encodings': <module 'encodings' from '/Users/cor/miniconda3/envs/example-project/lib/python3.7/encodings/__init__.py'>,
#  'codecs': <module 'codecs' from '/Users/cor/miniconda3/envs/example-project/lib/python3.7/codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'encodings.aliases': <module 'encodings.aliases' from '/Users/cor/miniconda3/envs/example-project/lib/python3.7/encodings/aliases.py'>,
# ...

# %%
del sys.modules['loader']
